# %%
import pandas as pd

# %%
data = {
    'Maxine': [98.6, 99.1, 100.2],
    'James': [97.9, 98.4, 99.0],
    'Amanda': [98.2, 99.5, 100.1]
}
temperatures = pd.DataFrame(data)
print("(a): DataFrame named temperatures:\n", temperatures)

temperatures.index = ['Morning', 'Afternoon', 'Evening']
print("\n(b): DataFrame with custom indices:\n", temperatures)

maxine_temps = temperatures['Maxine']
print("\n(c): Column of temperature readings for Maxine:\n", maxine_temps)

morning_temps = temperatures.loc['Morning']
print("\n(d): Row of 'Morning' temperature readings:\n", morning_temps)

morning_evening_temps = temperatures.loc[['Morning', 'Evening']]
print("\n(e): Rows for 'Morning' and 'Evening' temperature readings:\n", morning_evening_temps)

amanda_maxine_temps = temperatures[['Amanda', 'Maxine']]
print("\n(f): Columns of temperature readings for Amanda and Maxine:\n", amanda_maxine_temps)

specific_temps = temperatures.loc[['Morning', 'Afternoon'], ['Amanda', 'Maxine']]
print("\n(g): Elements for Amanda and Maxine in Morning and Afternoon:\n", specific_temps)

print("\n(h): Descriptive statistics of temperatures:\n", temperatures.describe())

transposed_temps = temperatures.T
print("\n(i): Transposed DataFrame:\n", transposed_temps)

sorted_temps = temperatures.reindex(sorted(temperatures.columns), axis=1)
print("\n(j): DataFrame with columns sorted in alphabetical order:\n", sorted_temps)
# Out:
# (a): DataFrame named temperatures:
#     Maxine  James  Amanda
# 0    98.6   97.9    98.2
# 1    99.1   98.4    99.5
# 2   100.2   99.0   100.1
#
# (b): DataFrame with custom indices:
#             Maxine  James  Amanda
# Morning      98.6   97.9    98.2
# Afternoon    99.1   98.4    99.5
# Evening     100.2   99.0   100.1
#
# (c): Column of temperature readings for Maxine:
#  Morning       98.6
# Afternoon     99.1
# Evening      100.2
# Name: Maxine, dtype: float64
#
# (d): Row of 'Morning' temperature readings:
#  Maxine    98.6
# James     97.9
# Amanda    98.2
# Name: Morning, dtype: float64
#
# (e): Rows for 'Morning' and 'Evening' temperature readings:
#           Maxine  James  Amanda
# Morning    98.6   97.9    98.2
# Evening   100.2   99.0   100.1
#
# (f): Columns of temperature readings for Amanda and Maxine:
#             Amanda  Maxine
# Morning      98.2    98.6
# Afternoon    99.5    99.1
# Evening     100.1   100.2
#
# (g): Elements for Amanda and Maxine in Morning and Afternoon:
#             Amanda  Maxine
# Morning      98.2    98.6
# Afternoon    99.5    99.1
#
# (h): Descriptive statistics of temperatures:
#             Maxine      James      Amanda
# count    3.000000   3.000000    3.000000
# mean    99.300000  98.433333   99.266667
# std      0.818535   0.550757    0.971253
# min     98.600000  97.900000   98.200000
# 25%     98.850000  98.150000   98.850000
# 50%     99.100000  98.400000   99.500000
# 75%     99.650000  98.700000   99.800000
# max    100.200000  99.000000  100.100000
#
# (i): Transposed DataFrame:
#          Morning  Afternoon  Evening
# Maxine     98.6       99.1    100.2
# James      97.9       98.4     99.0
# Amanda     98.2       99.5    100.1
#
# (j): DataFrame with columns sorted in alphabetical order:
#             Amanda  James  Maxine
# Morning      98.2   97.9    98.6
# Afternoon    99.5   98.4    99.1
# Evening     100.1   99.0   100.2
